# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('stmt.csv')
data
# Out:
#          Date                                        Description   Amount  \
# 0      9/1/17                 Beginning balance as of 09/01/2017      NaN
# 1      9/5/17                                            Deposit   784.00
# 2      9/5/17  Square Inc DES:170904P2 ID:L201237538643 INDN:...    67.40
# 3      9/5/17  CHECKCARD 0901 STARTEC*LGDISTANCE INT 800-479-...    -8.44
# 4      9/5/17  WALGREENS STOR 09/02 #000626739 PURCHASE WALGR...   -15.09
# 5      9/5/17  CHECKCARD 0904 CHEVRON 0202655 BOCA RATON FL 2...  -100.00
# 6      9/5/17                                         Check 1002   -79.32
# 7      9/6/17  WALGREENS STOR 09/06 #000501421 PURCHASE WALGR...  -153.39
# 8      9/6/17  LOWE'S #1069 09/06 #000988668 PURCHASE LOWE'S ...  -183.80
# 9      9/6/17                                         Check 1003   -64.34
# 10     9/6/17  Credit One Bank DES:Payment ID:XXXXX17143874 I...    -8.26
# 11     9/7/17  PUBLIX SUPER M 09/07 #000001296 PURCHASE PUBLI...  -187.64
# ...

# %%
data.describe()
# Out:
#             Amount  Running Bal.
# count   167.000000    168.000000
# mean    -14.663713   4613.696250
# std    1377.507897   1948.097999
# min   -8000.000000   1126.050000
# 25%    -200.000000   3503.915000
# 50%     -38.780000   4229.315000
# 75%      90.295000   5104.397500
# max    5770.690000  10189.910000
