# %%
# Matplotlib is a most popular plotting library for Python!
# It gives you control over every aspect of a figure
# It was designed to have a similar feel to MatLab's graphical plotting
# conda install matplotlib

# %%
import matplotlib.pyplot as plt
# printing plot inside jupyter notebook
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2

# %%
y
# Out:
# array([  0.  ,   0.25,   1.  ,   2.25,   4.  ,   6.25,   9.  ,  12.25,
#         16.  ,  20.25,  25.  ])

# %%
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
# functional method creat plot
plt.plot(x,y)
plt.xlabel('X LABEL')
plt.ylabel('Y LABEL')
plt.title('TITLE')

# %%
# Mulit plots
plt.subplot(1,3,1)
plt.plot(x,y,'r')

plt.subplot(1,3,2)
plt.plot(y,x,'b')

plt.subplot(1,3,3)
plt.plot(y,x,'b')

# %%
# Object Oriented Method
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('x label')
axes.set_ylabel('y label')
axes.set_title('title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.6,0.2,0.2])

axes1.plot(x,y)
axes1.set_title('Larger PLOT')
axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)
# for current_axes in axes:
 #   current_axes.plot(x,y)
# indexing method    
axes[0].plot(x,y)
axes[0].set_title('0 index title')
axes[1].plot(y,x)
axes[1].set_title('1 index title')

# fix plots
plt.tight_layout()

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x116282c50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x116354f60>], dtype=object)

# %%
# FIG Size and DPI

# %%
fig = plt.figure(figsize=(8,5),dpi=100)
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2, figsize=(8,2))
   
axes[0].plot(x,y)
axes[0].set_title('0 index title')

axes[1].plot(y,x)
axes[1].set_title('1 index title')

# %%
fig,axes = plt.subplots(nrows=2, ncols=1, figsize=(8,4))
   
axes[0].plot(x,y)
axes[0].set_title('0 index title')

axes[1].plot(y,x)
axes[1].set_title('1 index title')

plt.tight_layout()

# %%
fig.savefig('my_picture.png', dpi=200)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

ax.set_title('Title')
ax.set_xlabel('X label')
ax.set_ylabel('y label')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, label = "first label")
ax.plot(y,x, label = "secund label")
ax.legend()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, label = "first label")
ax.plot(y,x, label = "secund label")
ax.legend(loc=10)

# %%
# Setting colors, lines ... styling plot
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='Red', linewidth=3, alpha=0.7, linestyle = '--', marker='o', markersize=15, 
        markerfacecolor='yellow', markeredgewidth=3, markeredgecolor='green') # RGB Hex Code 
# linewidth or lw

# %%
len(x)
# Out:
# 11

# %%
# Control over axis appearance 
# Plot Range

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='Red', linewidth=2, ls='--')

ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0, 2)
